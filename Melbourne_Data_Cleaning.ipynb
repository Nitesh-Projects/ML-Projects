# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
 data = pd.read_csv('C:/python/Melborn House Price Prediction/Melbourne_housing_price.csv')

# %%
data
# Out:
#            Suburb             Address  Rooms Type      Price Method  \
# 0      Abbotsford       68 Studley St      2    h        NaN     SS
# 1      Abbotsford        85 Turner St      2    h  1480000.0      S
# 2      Abbotsford     25 Bloomburg St      2    h  1035000.0      S
# 3      Abbotsford  18/659 Victoria St      3    u        NaN     VB
# 4      Abbotsford        5 Charles St      3    h  1465000.0     SP
# ...           ...                 ...    ...  ...        ...    ...
# 34852  Yarraville         13 Burns St      4    h  1480000.0     PI
# 34853  Yarraville       29A Murray St      2    h   888000.0     SP
# 34854  Yarraville      147A Severn St      2    t   705000.0      S
# 34855  Yarraville    12/37 Stephen St      3    h  1140000.0     SP
# 34856  Yarraville    3 Tarrengower St      2    h  1020000.0     PI
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 0             Jellis   3/09/2016       2.5    3067.0  ...       1.0  1.0
# ...

# %%
data.shape
# Out:
# (34857, 21)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34857 entries, 0 to 34856
# Data columns (total 21 columns):
# Suburb           34857 non-null object
# Address          34857 non-null object
# Rooms            34857 non-null int64
# Type             34857 non-null object
# Price            27247 non-null float64
# Method           34857 non-null object
# SellerG          34857 non-null object
# Date             34857 non-null object
# Distance         34856 non-null float64
# Postcode         34856 non-null float64
# Bedroom2         26640 non-null float64
# Bathroom         26631 non-null float64
# Car              26129 non-null float64
# Landsize         23047 non-null float64
# BuildingArea     13742 non-null float64
# YearBuilt        15551 non-null float64
# CouncilArea      34854 non-null object
# Lattitude        26881 non-null float64
# Longtitude       26881 non-null float64
# Regionname       34854 non-null object
# Propertycount    34854 non-null float64
# ...

# %%
data.isnull().sum().sort_values(ascending = False)
# Out:
# BuildingArea     21115
# YearBuilt        19306
# Landsize         11810
# Car               8728
# Bathroom          8226
# Bedroom2          8217
# Longtitude        7976
# Lattitude         7976
# Price             7610
# Regionname           3
# Propertycount        3
# CouncilArea          3
# Postcode             1
# Distance             1
# Date                 0
# SellerG              0
# Method               0
# Type                 0
# Rooms                0
# Address              0
# Suburb               0
# dtype: int64

# %%
data.isnull().sum(axis = 1).sort_values(ascending = False)
# Out:
# 29483    13
# 18523    11
# 26888    11
# 13203     9
# 26673     9
#          ..
# 25354     0
# 25356     0
# 25362     0
# 9917      0
# 34856     0
# Length: 34857, dtype: int64

# %%
# percent of values missing in data

# %%
data.isnull().sum().sort_values(ascending = False)/len(data)*100
# Out:
# BuildingArea     60.576068
# YearBuilt        55.386293
# Landsize         33.881286
# Car              25.039447
# Bathroom         23.599277
# Bedroom2         23.573457
# Longtitude       22.882061
# Lattitude        22.882061
# Price            21.832057
# Regionname        0.008607
# Propertycount     0.008607
# CouncilArea       0.008607
# Postcode          0.002869
# Distance          0.002869
# Date              0.000000
# SellerG           0.000000
# Method            0.000000
# Type              0.000000
# Rooms             0.000000
# Address           0.000000
# Suburb            0.000000
# dtype: float64

# %%
data.isnull().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# YearBuilt        19306
# CouncilArea          3
# Lattitude         7976
# Longtitude        7976
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
#atleast one value is missing
d = data.isnull().sum()>0
d
# Out:
# Suburb           False
# Address          False
# Rooms            False
# Type             False
# Price             True
# Method           False
# SellerG          False
# Date             False
# Distance          True
# Postcode          True
# Bedroom2          True
# Bathroom          True
# Car               True
# Landsize          True
# BuildingArea      True
# YearBuilt         True
# CouncilArea       True
# Lattitude         True
# Longtitude        True
# Regionname        True
# Propertycount     True
# dtype: bool

# %%
d.index
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
d.values
# Out:
# array([False, False, False, False,  True, False, False, False,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True])

# %%
#these columns have atleast one Null Value
d.index[d.values]
# Out:
# Index(['Price', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
len(d.index[d.values]) #14 out of 21 columns have atleast one null value
# Out:
# 14

# %%
# to check null value in rows

# %%
rowmissing = data.isnull().sum(axis =1)>0

# %%
rowmissing
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4        False
#          ...
# 34852     True
# 34853    False
# 34854    False
# 34855     True
# 34856    False
# Length: 34857, dtype: bool

# %%
rowmissing.index
# Out:
# RangeIndex(start=0, stop=34857, step=1)

# %%
rowmissing.values
# Out:
# array([ True,  True, False, ..., False,  True, False])

# %%
row = rowmissing.index[rowmissing.values]

# %%
len(row)
# Out:
# 25970

# %%
#these rows have atleast one missing value
row2 = data.iloc[row,:]

# %%
row2
# Out:
#            Suburb             Address  Rooms Type      Price Method  \
# 0      Abbotsford       68 Studley St      2    h        NaN     SS
# 1      Abbotsford        85 Turner St      2    h  1480000.0      S
# 3      Abbotsford  18/659 Victoria St      3    u        NaN     VB
# 5      Abbotsford    40 Federation La      3    h   850000.0     PI
# 7      Abbotsford        16 Maugie St      4    h        NaN     SN
# ...           ...                 ...    ...  ...        ...    ...
# 34848     Wollert       16 Gunther Wy      4    h   621000.0      S
# 34850     Wollert    15 Rockgarden Wy      3    h        NaN     SP
# 34851  Yarraville       78 Bayview Rd      3    h  1101000.0      S
# 34852  Yarraville         13 Burns St      4    h  1480000.0     PI
# 34855  Yarraville    12/37 Stephen St      3    h  1140000.0     SP
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 0             Jellis   3/09/2016       2.5    3067.0  ...       1.0  1.0
# ...

# %%
#any column having all missing value

# %%
data.isnull().all(axis =0)
# Out:
# Suburb           False
# Address          False
# Rooms            False
# Type             False
# Price            False
# Method           False
# SellerG          False
# Date             False
# Distance         False
# Postcode         False
# Bedroom2         False
# Bathroom         False
# Car              False
# Landsize         False
# BuildingArea     False
# YearBuilt        False
# CouncilArea      False
# Lattitude        False
# Longtitude       False
# Regionname       False
# Propertycount    False
# dtype: bool

# %%
#check any row having all missing values

# %%
data.isnull().all(axis=1)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 34852    False
# 34853    False
# 34854    False
# 34855    False
# 34856    False
# Length: 34857, dtype: bool

# %%
len(data.isnull().all(axis=1))
# Out:
# 34857

# %%
data.shape
# Out:
# (34857, 21)

# %%
data.isnull().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# YearBuilt        19306
# CouncilArea          3
# Lattitude         7976
# Longtitude        7976
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
data.isnull().sum().sort_values(ascending = False)/len(data)*100
# Out:
# BuildingArea     60.576068
# YearBuilt        55.386293
# Landsize         33.881286
# Car              25.039447
# Bathroom         23.599277
# Bedroom2         23.573457
# Longtitude       22.882061
# Lattitude        22.882061
# Price            21.832057
# Regionname        0.008607
# Propertycount     0.008607
# CouncilArea       0.008607
# Postcode          0.002869
# Distance          0.002869
# Date              0.000000
# SellerG           0.000000
# Method            0.000000
# Type              0.000000
# Rooms             0.000000
# Address           0.000000
# Suburb            0.000000
# dtype: float64

# %%
round(data.isnull().sum().sort_values(ascending = False)/len(data)*100,2)
# Out:
# BuildingArea     60.58
# YearBuilt        55.39
# Landsize         33.88
# Car              25.04
# Bathroom         23.60
# Bedroom2         23.57
# Longtitude       22.88
# Lattitude        22.88
# Price            21.83
# Regionname        0.01
# Propertycount     0.01
# CouncilArea       0.01
# Postcode          0.00
# Distance          0.00
# Date              0.00
# SellerG           0.00
# Method            0.00
# Type              0.00
# Rooms             0.00
# Address           0.00
# Suburb            0.00
# dtype: float64

# %%
#revomeing columns with maximum 3 null values columns

# %%
data.isnull().sum().sort_values(ascending = False).head(2)
# Out:
# BuildingArea    21115
# YearBuilt       19306
# dtype: int64

# %%
data.isnull().sum().sort_values(ascending = False).head(2).index
# Out:
# Index(['BuildingArea', 'YearBuilt'], dtype='object')

# %%
col=data.isnull().sum().sort_values(ascending = False).head(2).index.values

# %%
col
# Out:
# array(['BuildingArea', 'YearBuilt'], dtype=object)

# %%
data = data.drop(col,axis = 'columns')

# %%
data
# Out:
#            Suburb             Address  Rooms Type      Price Method  \
# 0      Abbotsford       68 Studley St      2    h        NaN     SS
# 1      Abbotsford        85 Turner St      2    h  1480000.0      S
# 2      Abbotsford     25 Bloomburg St      2    h  1035000.0      S
# 3      Abbotsford  18/659 Victoria St      3    u        NaN     VB
# 4      Abbotsford        5 Charles St      3    h  1465000.0     SP
# ...           ...                 ...    ...  ...        ...    ...
# 34852  Yarraville         13 Burns St      4    h  1480000.0     PI
# 34853  Yarraville       29A Murray St      2    h   888000.0     SP
# 34854  Yarraville      147A Severn St      2    t   705000.0      S
# 34855  Yarraville    12/37 Stephen St      3    h  1140000.0     SP
# 34856  Yarraville    3 Tarrengower St      2    h  1020000.0     PI
#
#              SellerG        Date  Distance  Postcode  Bedroom2  Bathroom  Car  \
# ...

# %%
data.shape
# Out:
# (34857, 19)

# %%
#clean the data
round(data.isnull().sum().sort_values(ascending = False)/len(data)*100,2)
# Out:
# Landsize         33.88
# Car              25.04
# Bathroom         23.60
# Bedroom2         23.57
# Longtitude       22.88
# Lattitude        22.88
# Price            21.83
# Propertycount     0.01
# CouncilArea       0.01
# Regionname        0.01
# Postcode          0.00
# Distance          0.00
# Date              0.00
# SellerG           0.00
# Method            0.00
# Type              0.00
# Rooms             0.00
# Address           0.00
# Suburb            0.00
# dtype: float64

# %%
#now seeing rows with more than 5 missing values

# %%
p = data[data.isnull().sum(axis = 1)>5]

# %%
p
# Out:
#              Suburb              Address  Rooms Type      Price Method  \
# 15       Abbotsford     217 Langridge St      3    h  1000000.0      S
# 16       Abbotsford      18a Mollison St      2    t   745000.0      S
# 19       Abbotsford  403/609 Victoria St      2    u   542000.0      S
# 21       Abbotsford    25/84 Trenerry Cr      2    u   760000.0     SP
# 22       Abbotsford    106/119 Turner St      1    u   481000.0     SP
# ...             ...                  ...    ...  ...        ...    ...
# 34838  Williamstown   11/81 Melbourne Rd      2    u   450000.0     SP
# 34839  Williamstown     24/18 Station Rd      2    u   475000.0     SP
# 34840  Williamstown      3/2 Thompson St      2    u   520000.0     VB
# 34844       Windsor     4/16 Lewisham Rd      1    u   440000.0     SP
# 34855    Yarraville     12/37 Stephen St      3    h  1140000.0     SP
#
#              SellerG        Date  Distance  Postcode  Bedroom2  Bathroom  Car  \
# ...

# %%
len(p)
# Out:
# 7950

# %%
len(p)/len(data)
# Out:
# 0.22807470522420173

# %%
# 22% of the rows have more than 5 missing values

# %%
data = data[data.isnull().sum(axis =1)<=5]

# %%
# this data has missing values less than 5 in each row

# %%
data
# Out:
#            Suburb             Address  Rooms Type      Price Method  SellerG  \
# 0      Abbotsford       68 Studley St      2    h        NaN     SS   Jellis
# 1      Abbotsford        85 Turner St      2    h  1480000.0      S   Biggin
# 2      Abbotsford     25 Bloomburg St      2    h  1035000.0      S   Biggin
# 3      Abbotsford  18/659 Victoria St      3    u        NaN     VB   Rounds
# 4      Abbotsford        5 Charles St      3    h  1465000.0     SP   Biggin
# ...           ...                 ...    ...  ...        ...    ...      ...
# 34851  Yarraville       78 Bayview Rd      3    h  1101000.0      S      Jas
# 34852  Yarraville         13 Burns St      4    h  1480000.0     PI      Jas
# 34853  Yarraville       29A Murray St      2    h   888000.0     SP  Sweeney
# 34854  Yarraville      147A Severn St      2    t   705000.0      S      Jas
# 34856  Yarraville    3 Tarrengower St      2    h  1020000.0     PI       RW
#
# ...

# %%
26907/34857
# Out:
# 0.7719252947757983

# %%
round(data.isnull().sum().sort_values(ascending = False)/len(data)*100,2)
# Out:
# Price            21.90
# Landsize         14.35
# Car               2.89
# Bathroom          1.03
# Bedroom2          0.99
# Longtitude        0.10
# Lattitude         0.10
# Propertycount     0.00
# Method            0.00
# Address           0.00
# Rooms             0.00
# Type              0.00
# Postcode          0.00
# SellerG           0.00
# Date              0.00
# Distance          0.00
# Regionname        0.00
# CouncilArea       0.00
# Suburb            0.00
# dtype: float64

# %%
#price is target so cant remove all but we can remove all the row of those missing vales

# %%
data['Price'].notnull()
# Out:
# 0        False
# 1         True
# 2         True
# 3        False
# 4         True
#          ...
# 34851     True
# 34852     True
# 34853     True
# 34854     True
# 34856     True
# Name: Price, Length: 26907, dtype: bool

# %%
data = data[data['Price'].notnull()]

# %%
data
# Out:
#            Suburb           Address  Rooms Type      Price Method  SellerG  \
# 1      Abbotsford      85 Turner St      2    h  1480000.0      S   Biggin
# 2      Abbotsford   25 Bloomburg St      2    h  1035000.0      S   Biggin
# 4      Abbotsford      5 Charles St      3    h  1465000.0     SP   Biggin
# 5      Abbotsford  40 Federation La      3    h   850000.0     PI   Biggin
# 6      Abbotsford       55a Park St      4    h  1600000.0     VB   Nelson
# ...           ...               ...    ...  ...        ...    ...      ...
# 34851  Yarraville     78 Bayview Rd      3    h  1101000.0      S      Jas
# 34852  Yarraville       13 Burns St      4    h  1480000.0     PI      Jas
# 34853  Yarraville     29A Murray St      2    h   888000.0     SP  Sweeney
# 34854  Yarraville    147A Severn St      2    t   705000.0      S      Jas
# 34856  Yarraville  3 Tarrengower St      2    h  1020000.0     PI       RW
#
# ...

# %%
round(data.isnull().sum().sort_values(ascending = False)/len(data)*100,2)
# Out:
# Landsize         14.43
# Car               2.82
# Bathroom          1.02
# Bedroom2          0.99
# Longtitude        0.10
# Lattitude         0.10
# Propertycount     0.00
# Method            0.00
# Address           0.00
# Rooms             0.00
# Type              0.00
# Price             0.00
# Postcode          0.00
# SellerG           0.00
# Date              0.00
# Distance          0.00
# Regionname        0.00
# CouncilArea       0.00
# Suburb            0.00
# dtype: float64

# %%
data['Landsize'].describe()
# Out:
# count     17982.000000
# mean        593.488933
# std        3757.266429
# min           0.000000
# 25%         219.000000
# 50%         512.000000
# 75%         664.000000
# max      433014.000000
# Name: Landsize, dtype: float64

# %%
data
# Out:
#            Suburb           Address  Rooms Type      Price Method  SellerG  \
# 1      Abbotsford      85 Turner St      2    h  1480000.0      S   Biggin
# 2      Abbotsford   25 Bloomburg St      2    h  1035000.0      S   Biggin
# 4      Abbotsford      5 Charles St      3    h  1465000.0     SP   Biggin
# 5      Abbotsford  40 Federation La      3    h   850000.0     PI   Biggin
# 6      Abbotsford       55a Park St      4    h  1600000.0     VB   Nelson
# ...           ...               ...    ...  ...        ...    ...      ...
# 34851  Yarraville     78 Bayview Rd      3    h  1101000.0      S      Jas
# 34852  Yarraville       13 Burns St      4    h  1480000.0     PI      Jas
# 34853  Yarraville     29A Murray St      2    h   888000.0     SP  Sweeney
# 34854  Yarraville    147A Severn St      2    t   705000.0      S      Jas
# 34856  Yarraville  3 Tarrengower St      2    h  1020000.0     PI       RW
#
# ...

# %%
len(data['Landsize'].notnull())
# Out:
# 21015

# %%
data = data[data['Landsize'].notnull()]
data
# Out:
#            Suburb           Address  Rooms Type      Price Method  SellerG  \
# 1      Abbotsford      85 Turner St      2    h  1480000.0      S   Biggin
# 2      Abbotsford   25 Bloomburg St      2    h  1035000.0      S   Biggin
# 4      Abbotsford      5 Charles St      3    h  1465000.0     SP   Biggin
# 5      Abbotsford  40 Federation La      3    h   850000.0     PI   Biggin
# 6      Abbotsford       55a Park St      4    h  1600000.0     VB   Nelson
# ...           ...               ...    ...  ...        ...    ...      ...
# 34851  Yarraville     78 Bayview Rd      3    h  1101000.0      S      Jas
# 34852  Yarraville       13 Burns St      4    h  1480000.0     PI      Jas
# 34853  Yarraville     29A Murray St      2    h   888000.0     SP  Sweeney
# 34854  Yarraville    147A Severn St      2    t   705000.0      S      Jas
# 34856  Yarraville  3 Tarrengower St      2    h  1020000.0     PI       RW
#
# ...

# %%
round(data.isnull().sum().sort_values(ascending = False)/len(data)*100,2)
# Out:
# Car              1.56
# Longtitude       0.12
# Lattitude        0.12
# Bathroom         0.05
# Bedroom2         0.03
# Propertycount    0.00
# SellerG          0.00
# Address          0.00
# Rooms            0.00
# Type             0.00
# Price            0.00
# Method           0.00
# Postcode         0.00
# Date             0.00
# Distance         0.00
# Regionname       0.00
# Landsize         0.00
# CouncilArea      0.00
# Suburb           0.00
# dtype: float64

# %%
#now for the remaining we need to clean the data

# %%
data.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'CouncilArea', 'Lattitude', 'Longtitude', 'Regionname',
#        'Propertycount'],
#       dtype='object')

# %%
data.loc[:,['Car','Lattitude', 'Longtitude','Bedroom2', 'Bathroom']]
# Out:
#        Car  Lattitude  Longtitude  Bedroom2  Bathroom
# 1      1.0  -37.79960   144.99840       2.0       1.0
# 2      0.0  -37.80790   144.99340       2.0       1.0
# 4      0.0  -37.80930   144.99440       3.0       2.0
# 5      1.0  -37.79690   144.99690       3.0       2.0
# 6      2.0  -37.80720   144.99410       3.0       1.0
# ...    ...        ...         ...       ...       ...
# 34851  NaN  -37.81095   144.88516       3.0       1.0
# 34852  3.0  -37.81053   144.88467       4.0       1.0
# 34853  1.0  -37.81551   144.88826       2.0       2.0
# 34854  2.0  -37.82286   144.87856       2.0       1.0
# 34856  0.0  -37.81810   144.89351       2.0       1.0
#
# [17982 rows x 5 columns]

# %%
data.loc[:,['Car','Lattitude', 'Longtitude','Bedroom2', 'Bathroom']].describe()
# Out:
#                 Car     Lattitude    Longtitude      Bedroom2      Bathroom
# count  17701.000000  17960.000000  17960.000000  17976.000000  17973.000000
# mean       1.698887    -37.806490    144.995942      3.033100      1.580871
# std        0.998673      0.089034      0.116992      0.954873      0.702912
# min        0.000000    -38.190430    144.423790      0.000000      0.000000
# 25%        1.000000    -37.858900    144.925300      2.000000      1.000000
# 50%        2.000000    -37.800020    145.002000      3.000000      1.000000
# 75%        2.000000    -37.750170    145.066800      4.000000      2.000000
# max       18.000000    -37.399460    145.526350     20.000000      9.000000

# %%
#replacing the Latitude and Logitude with mean

# %%
mean_latti=data['Lattitude'].mean()

# %%
mean_latti
# Out:
# -37.806490380289596

# %%
data['Lattitude']
# Out:
# 1       -37.79960
# 2       -37.80790
# 4       -37.80930
# 5       -37.79690
# 6       -37.80720
#            ...
# 34851   -37.81095
# 34852   -37.81053
# 34853   -37.81551
# 34854   -37.82286
# 34856   -37.81810
# Name: Lattitude, Length: 17982, dtype: float64

# %%
data.loc[:,'Lattitude'].fillna(mean_latti)
# Out:
# 1       -37.79960
# 2       -37.80790
# 4       -37.80930
# 5       -37.79690
# 6       -37.80720
#            ...
# 34851   -37.81095
# 34852   -37.81053
# 34853   -37.81551
# 34854   -37.82286
# 34856   -37.81810
# Name: Lattitude, Length: 17982, dtype: float64

# %%
data.loc[:,'Lattitude'].fillna(mean_latti,inplace = True)

# %%
data.isnull().sum().sort_values(ascending = True)
# Out:
# Suburb             0
# Lattitude          0
# CouncilArea        0
# Landsize           0
# Regionname         0
# Distance           0
# Date               0
# Postcode           0
# Method             0
# Price              0
# Type               0
# Rooms              0
# Address            0
# SellerG            0
# Propertycount      0
# Bedroom2           6
# Bathroom           9
# Longtitude        22
# Car              281
# dtype: int64

# %%
mean_long=data['Longtitude'].mean()

# %%
mean_long
# Out:
# 144.99594155790686

# %%
data.loc[:,'Longtitude'].fillna(mean_long,inplace = True)

# %%
data.isnull().sum().sort_values(ascending = True)
# Out:
# Suburb             0
# Longtitude         0
# Lattitude          0
# CouncilArea        0
# Landsize           0
# Regionname         0
# Distance           0
# Postcode           0
# SellerG            0
# Method             0
# Price              0
# Type               0
# Rooms              0
# Address            0
# Date               0
# Propertycount      0
# Bedroom2           6
# Bathroom           9
# Car              281
# dtype: int64

# %%
data.isnull().sum().sort_values(ascending = True)/len(data)*100
# Out:
# Suburb           0.000000
# Longtitude       0.000000
# Lattitude        0.000000
# CouncilArea      0.000000
# Landsize         0.000000
# Regionname       0.000000
# Distance         0.000000
# Postcode         0.000000
# SellerG          0.000000
# Method           0.000000
# Price            0.000000
# Type             0.000000
# Rooms            0.000000
# Address          0.000000
# Date             0.000000
# Propertycount    0.000000
# Bedroom2         0.033367
# Bathroom         0.050050
# Car              1.562674
# dtype: float64

# %%
data.loc[:,['Bathroom','Bedroom2','Car']].describe()
# Out:
#            Bathroom      Bedroom2           Car
# count  17973.000000  17976.000000  17701.000000
# mean       1.580871      3.033100      1.698887
# std        0.702912      0.954873      0.998673
# min        0.000000      0.000000      0.000000
# 25%        1.000000      2.000000      1.000000
# 50%        1.000000      3.000000      2.000000
# 75%        2.000000      4.000000      2.000000
# max        9.000000     20.000000     18.000000

# %%
data['Car'].mode()
# Out:
# 0    2.0
# dtype: float64

# %%
data['Bedroom2'].mode()
# Out:
# 0    3.0
# dtype: float64

# %%
data['Bathroom'].mode()
# Out:
# 0    1.0
# dtype: float64

# %%
data['Car'].astype('category').value_counts()
# Out:
# 2.0     7970
# 1.0     6483
# 0.0     1178
# 3.0     1065
# 4.0      778
# 5.0       99
# 6.0       92
# 7.0       16
# 8.0       12
# 10.0       4
# 9.0        2
# 18.0       1
# 11.0       1
# Name: Car, dtype: int64

# %%
data.loc[:,'Car'].fillna(2,inplace = True)

# %%
data.isnull().sum().sort_values()
# Out:
# Suburb           0
# Longtitude       0
# Lattitude        0
# CouncilArea      0
# Landsize         0
# Car              0
# Regionname       0
# Distance         0
# Postcode         0
# SellerG          0
# Method           0
# Price            0
# Type             0
# Rooms            0
# Address          0
# Date             0
# Propertycount    0
# Bedroom2         6
# Bathroom         9
# dtype: int64

# %%
data.loc[:,'Bedroom2'].fillna(3,inplace = True)

# %%
data.isnull().sum().sort_values()
# Out:
# Suburb           0
# Longtitude       0
# Lattitude        0
# CouncilArea      0
# Landsize         0
# Car              0
# Bedroom2         0
# Regionname       0
# Postcode         0
# Date             0
# SellerG          0
# Method           0
# Price            0
# Type             0
# Rooms            0
# Address          0
# Distance         0
# Propertycount    0
# Bathroom         9
# dtype: int64

# %%
data.loc[:,'Bathroom'].fillna(1,inplace = True)

# %%
data
# Out:
#            Suburb           Address  Rooms Type      Price Method  SellerG  \
# 1      Abbotsford      85 Turner St      2    h  1480000.0      S   Biggin
# 2      Abbotsford   25 Bloomburg St      2    h  1035000.0      S   Biggin
# 4      Abbotsford      5 Charles St      3    h  1465000.0     SP   Biggin
# 5      Abbotsford  40 Federation La      3    h   850000.0     PI   Biggin
# 6      Abbotsford       55a Park St      4    h  1600000.0     VB   Nelson
# ...           ...               ...    ...  ...        ...    ...      ...
# 34851  Yarraville     78 Bayview Rd      3    h  1101000.0      S      Jas
# 34852  Yarraville       13 Burns St      4    h  1480000.0     PI      Jas
# 34853  Yarraville     29A Murray St      2    h   888000.0     SP  Sweeney
# 34854  Yarraville    147A Severn St      2    t   705000.0      S      Jas
# 34856  Yarraville  3 Tarrengower St      2    h  1020000.0     PI       RW
#
# ...

# %%
data.isnull().sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# CouncilArea      0
# Lattitude        0
# Longtitude       0
# Regionname       0
# Propertycount    0
# dtype: int64

# %%
data
# Out:
#            Suburb           Address  Rooms Type      Price Method  SellerG  \
# 1      Abbotsford      85 Turner St      2    h  1480000.0      S   Biggin
# 2      Abbotsford   25 Bloomburg St      2    h  1035000.0      S   Biggin
# 4      Abbotsford      5 Charles St      3    h  1465000.0     SP   Biggin
# 5      Abbotsford  40 Federation La      3    h   850000.0     PI   Biggin
# 6      Abbotsford       55a Park St      4    h  1600000.0     VB   Nelson
# ...           ...               ...    ...  ...        ...    ...      ...
# 34851  Yarraville     78 Bayview Rd      3    h  1101000.0      S      Jas
# 34852  Yarraville       13 Burns St      4    h  1480000.0     PI      Jas
# 34853  Yarraville     29A Murray St      2    h   888000.0     SP  Sweeney
# 34854  Yarraville    147A Severn St      2    t   705000.0      S      Jas
# 34856  Yarraville  3 Tarrengower St      2    h  1020000.0     PI       RW
#
# ...

# %%
data.shape
# Out:
# (17982, 19)
