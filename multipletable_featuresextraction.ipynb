# %%
import numpy as np

# %%
import pandas as pd

# %%
df1 = pd.read_csv('C:/python/Covid_Latest/raw_data1.csv')
df2 = pd.read_csv('C:/python/Covid_Latest/raw_data2.csv')
df3 = pd.read_csv('C:/python/Covid_Latest/raw_data3.csv')
df4 = pd.read_csv('C:/python/Covid_Latest/raw_data4.csv')
df5 = pd.read_csv('C:/python/Covid_Latest/raw_data5.csv')
df6 = pd.read_csv('C:/python/Covid_Latest/raw_data6.csv')
df7 = pd.read_csv('C:/python/Covid_Latest/raw_data7.csv')
df8 = pd.read_csv('C:/python/Covid_Latest/raw_data8.csv')
df9 = pd.read_csv('C:/python/Covid_Latest/raw_data9.csv')
df10 = pd.read_csv('C:/python/Covid_Latest/raw_data10.csv')

# %%
df1.columns
# Out:
# Index(['Patient Number', 'State Patient Number', 'Date Announced',
#        'Estimated Onset Date', 'Age Bracket', 'Gender', 'Detected City',
#        'Detected District', 'Detected State', 'State code', 'Current Status',
#        'Notes', 'Contracted from which Patient (Suspected)', 'Nationality',
#        'Type of transmission', 'Status Change Date', 'Source_1', 'Source_2',
#        'Source_3', 'Backup Notes', 'Num Cases'],
#       dtype='object')

# %%
len(df1.columns)
# Out:
# 21

# %%
len(df2.columns)
# Out:
# 21

# %%
len(df3.columns)
# Out:
# 20

# %%
df3.columns
# Out:
# Index(['Entry_ID', 'State Patient Number', 'Date Announced', 'Age Bracket',
#        'Gender', 'Detected City', 'Detected District', 'Detected State',
#        'State code', 'Num Cases', 'Current Status',
#        'Contracted from which Patient (Suspected)', 'Notes', 'Source_1',
#        'Source_2', 'Source_3', 'Nationality', 'Type of transmission',
#        'Status Change Date', 'Patient Number'],
#       dtype='object')

# %%
len(df4.columns)
# Out:
# 20

# %%
df1.columns == df2.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True])

# %%
df2.columns == df3.columns
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-160-5e2ff64f346a> in <module>
# ----> 1 df2.columns == df3.columns
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in cmp_method(self, other)
#     100         if isinstance(other, (np.ndarray, Index, ABCSeries)):
#     101             if other.ndim > 0 and len(self) != len(other):
# --> 102                 raise ValueError("Lengths must match to compare")
#     103
#     104         if is_object_dtype(self) and not isinstance(self, ABCMultiIndex):
#
# ValueError: Lengths must match to compare

# %%
df3.columns == df4.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True])

# %%
len(df5.columns)
# Out:
# 20

# %%
len(df6.columns)
# Out:
# 20

# %%
len(df7.columns)
# Out:
# 20

# %%
len(df8.columns)
# Out:
# 20

# %%
len(df9.columns)
# Out:
# 20

# %%
len(df10.columns)
# Out:
# 20

# %%
df4.columns == df5.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True])

# %%
df5.columns==df6.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True])

# %%
df6.columns == df7.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True])

# %%
df7.columns==df8.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True])

# %%
df8.columns == df9.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True])

# %%
 df9.columns==df10.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True])

# %%
#columns present in every table :
abc = list(set.intersection(*map(set,[df1,df2,df3,df4,df5,df6,df7,df8,df9,df10])))

# %%
abc
# Out:
# ['Source_1',
#  'Notes',
#  'Age Bracket',
#  'Contracted from which Patient (Suspected)',
#  'State code',
#  'Detected District',
#  'Date Announced',
#  'Detected State',
#  'Patient Number',
#  'Status Change Date',
#  'Num Cases',
#  'Nationality',
#  'Type of transmission',
#  'Detected City',
#  'Gender',
#  'Source_3',
#  'Current Status',
#  'State Patient Number',
#  'Source_2']

# %%
len(abc)
# Out:
# 19

# %%
p = set(df2).intersection(df3)
p
# Out:
# {'Age Bracket',
#  'Contracted from which Patient (Suspected)',
#  'Current Status',
#  'Date Announced',
#  'Detected City',
#  'Detected District',
#  'Detected State',
#  'Gender',
#  'Nationality',
#  'Notes',
#  'Num Cases',
#  'Patient Number',
#  'Source_1',
#  'Source_2',
#  'Source_3',
#  'State Patient Number',
#  'State code',
#  'Status Change Date',
#  'Type of transmission'}

# %%
len(p)
# Out:
# 19

# %%
q =set(df4).difference(df2)

# %%
q
#featues more in d2 and not there in d3
# Out:
# {'Entry_ID'}

# %%
q2 =set(df2).difference(df3)

# %%
q2
# Out:
# {'Backup Notes', 'Estimated Onset Date'}

# %%
df2.columns
# Out:
# Index(['Patient Number', 'State Patient Number', 'Date Announced',
#        'Estimated Onset Date', 'Age Bracket', 'Gender', 'Detected City',
#        'Detected District', 'Detected State', 'State code', 'Current Status',
#        'Notes', 'Contracted from which Patient (Suspected)', 'Nationality',
#        'Type of transmission', 'Status Change Date', 'Source_1', 'Source_2',
#        'Source_3', 'Backup Notes', 'Num Cases'],
#       dtype='object')

# %%
df3.columns
# Out:
# Index(['Entry_ID', 'State Patient Number', 'Date Announced', 'Age Bracket',
#        'Gender', 'Detected City', 'Detected District', 'Detected State',
#        'State code', 'Num Cases', 'Current Status',
#        'Contracted from which Patient (Suspected)', 'Notes', 'Source_1',
#        'Source_2', 'Source_3', 'Nationality', 'Type of transmission',
#        'Status Change Date', 'Patient Number'],
#       dtype='object')

# %%
df3
# Out:
#        Entry_ID State Patient Number Date Announced  Age Bracket Gender  \
# 0             1                  NaN     27/04/2020          NaN    NaN
# 1             2                  NaN     27/04/2020          NaN    NaN
# 2             3                  NaN     27/04/2020          NaN    NaN
# 3             4                  NaN     27/04/2020         28.0      M
# 4             5                  NaN     27/04/2020          NaN    NaN
# ...         ...                  ...            ...          ...    ...
# 10015     43270                  NaN     27/04/2020          NaN    NaN
# 10016     43271                  NaN     27/04/2020          NaN    NaN
# 10017     43272                  NaN     14/03/2020          NaN    NaN
# 10018     43273                  NaN     14/03/2020          NaN    NaN
# 10019     43274                  NaN     14/03/2020          NaN    NaN
#
#       Detected City Detected District    Detected State State code  Num Cases  \
# ...

# %%
q2 =set(df2) - set(df3)
#second way of getting the differnce

# %%
q2
# Out:
# {'Backup Notes', 'Estimated Onset Date'}

# %%
q3 =set(df3) - set(df2)

# %%
q3
#feature there in df3 but not in df2
# Out:
# {'Entry_ID'}

# %%
s= set(df2)

# %%
s
# Out:
# {'Age Bracket',
#  'Backup Notes',
#  'Contracted from which Patient (Suspected)',
#  'Current Status',
#  'Date Announced',
#  'Detected City',
#  'Detected District',
#  'Detected State',
#  'Estimated Onset Date',
#  'Gender',
#  'Nationality',
#  'Notes',
#  'Num Cases',
#  'Patient Number',
#  'Source_1',
#  'Source_2',
#  'Source_3',
#  'State Patient Number',
#  'State code',
#  'Status Change Date',
#  'Type of transmission'}

# %%
s2= set(df3)

# %%
s2
# Out:
# {'Age Bracket',
#  'Contracted from which Patient (Suspected)',
#  'Current Status',
#  'Date Announced',
#  'Detected City',
#  'Detected District',
#  'Detected State',
#  'Entry_ID',
#  'Gender',
#  'Nationality',
#  'Notes',
#  'Num Cases',
#  'Patient Number',
#  'Source_1',
#  'Source_2',
#  'Source_3',
#  'State Patient Number',
#  'State code',
#  'Status Change Date',
#  'Type of transmission'}

# %%
df1 = df1.rename(columns ={"Patient Number":"Entry_ID"})

# %%
df1
# Out:
#        Entry_ID State Patient Number Date Announced  Estimated Onset Date  \
# 0           1.0             KL-TS-P1     30/01/2020                   NaN
# 1           2.0             KL-AL-P1     02/02/2020                   NaN
# 2           3.0             KL-KS-P1     03/02/2020                   NaN
# 3           4.0                DL-P1     02/03/2020                   NaN
# 4           5.0                TS-P1     02/03/2020                   NaN
# ...         ...                  ...            ...                   ...
# 17359       NaN                  NaN     16/04/2020                   NaN
# 17360       NaN                  NaN     18/04/2020                   NaN
# 17361       NaN                  NaN     18/04/2020                   NaN
# 17362       NaN                  NaN     19/04/2020                   NaN
# 17363       NaN                  NaN     19/04/2020                   NaN
#
#       Age Bracket Gender             Detected City Detected District  \
# ...

# %%
df2 = df2.rename(columns ={"Patient Number":"Entry_ID"})

# %%
df2
# Out:
#        Entry_ID State Patient Number Date Announced  Estimated Onset Date  \
# 0       17307.0                  NaN     20/04/2020                   NaN
# 1       17308.0                  NaN     20/04/2020                   NaN
# 2       17309.0                  NaN     20/04/2020                   NaN
# 3       17310.0                  NaN     20/04/2020                   NaN
# 4       17311.0                  NaN     20/04/2020                   NaN
# ...         ...                  ...            ...                   ...
# 10814       NaN                  NaN     22/04/2020                   NaN
# 10815       NaN                  NaN     24/04/2020                   NaN
# 10816       NaN                  NaN     24/04/2020                   NaN
# 10817       NaN                  NaN     25/04/2020                   NaN
# 10818       NaN                  NaN     25/04/2020                   NaN
#
#        Age Bracket Gender Detected City Detected District Detected State  \
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10020 entries, 0 to 10019
# Data columns (total 20 columns):
# Entry_ID                                     10020 non-null int64
# State Patient Number                         5138 non-null object
# Date Announced                               10020 non-null object
# Age Bracket                                  5183 non-null float64
# Gender                                       4654 non-null object
# Detected City                                421 non-null object
# Detected District                            9934 non-null object
# Detected State                               10015 non-null object
# State code                                   10015 non-null object
# Num Cases                                    10019 non-null float64
# Current Status                               10020 non-null object
# Contracted from which Patient (Suspected)    241 non-null object
# ...

# %%
df2 = df2.drop(['Backup Notes', 'Estimated Onset Date'],axis=1)

# %%
df1 = df1.drop(['Backup Notes', 'Estimated Onset Date'],axis=1)

# %%
len(df1.columns)
# Out:
# 19

# %%
df1.columns
# Out:
# Index(['Entry_ID', 'State Patient Number', 'Date Announced', 'Age Bracket',
#        'Gender', 'Detected City', 'Detected District', 'Detected State',
#        'State code', 'Current Status', 'Notes',
#        'Contracted from which Patient (Suspected)', 'Nationality',
#        'Type of transmission', 'Status Change Date', 'Source_1', 'Source_2',
#        'Source_3', 'Num Cases'],
#       dtype='object')

# %%
len(df1.columns)
# Out:
# 19

# %%
df1
# Out:
#        Entry_ID State Patient Number Date Announced Age Bracket Gender  \
# 0           1.0             KL-TS-P1     30/01/2020          20      F
# 1           2.0             KL-AL-P1     02/02/2020         NaN    NaN
# 2           3.0             KL-KS-P1     03/02/2020         NaN    NaN
# 3           4.0                DL-P1     02/03/2020          45      M
# 4           5.0                TS-P1     02/03/2020          24      M
# ...         ...                  ...            ...         ...    ...
# 17359       NaN                  NaN     16/04/2020         NaN    NaN
# 17360       NaN                  NaN     18/04/2020         NaN    NaN
# 17361       NaN                  NaN     18/04/2020         NaN    NaN
# 17362       NaN                  NaN     19/04/2020         NaN    NaN
# 17363       NaN                  NaN     19/04/2020         NaN    NaN
#
#                   Detected City Detected District Detected State State code  \
# ...

# %%
df2
# Out:
#        Patient Number State Patient Number Date Announced  \
# 0             17307.0                  NaN     20/04/2020
# 1             17308.0                  NaN     20/04/2020
# 2             17309.0                  NaN     20/04/2020
# 3             17310.0                  NaN     20/04/2020
# 4             17311.0                  NaN     20/04/2020
# ...               ...                  ...            ...
# 10814             NaN                  NaN     22/04/2020
# 10815             NaN                  NaN     24/04/2020
# 10816             NaN                  NaN     24/04/2020
# 10817             NaN                  NaN     25/04/2020
# 10818             NaN                  NaN     25/04/2020
#
#        Estimated Onset Date  Age Bracket Gender Detected City  \
# 0                       NaN         48.0      M           NaN
# 1                       NaN         55.0      M           NaN
# 2                       NaN         57.0      M           NaN
# ...
